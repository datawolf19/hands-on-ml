# %% [markdown]
# ## ML Practice: Analyzing Lending Club Loan Data
#
# We will take the features to determine what the qualifying loan amount that the individual would be approved for.

# %%
import psycopg2 as pg
import pandas as pd
import numpy as np
import zipfile
import sqlalchemy
import os 
# %matplotlib inline
from matplotlib import pyplot as plt
import seaborn as sns
from utils.secrets import creds

# %%
pd.options.display.max_columns = 170

# %%
creds = creds['postgres']

# %%
# Changed Username & Password to import from secrets file.
conn_str = f"postgresql+psycopg2://{creds['username']}:{creds['password']}@localhost/Kaggle"
engine = sqlalchemy.create_engine(conn_str)
metadata = sqlalchemy.MetaData(schema='lending_club')

# %% [markdown]
# # Lending Tree Data

# %%
# Only used for loading a couple rows into the database to create the underlying columns + datatypes
# Later import csv using dbeaver. 

# file = os.path.expanduser('~') + '/datasets/loan.csv'
# pd.read_csv(file, nrows=3).to_sql('loan', con=engine, index=False, if_exists='replace', schema='lending_club')

# %%
df = pd.read_sql('select * from lending_club.loan tablesample system(.4)', con=engine)

# %%
df.shape
# Out:
# (8654, 151)

# %%
hist = df.loan_amt.hist()

# %%
sample_mean_05 = pd.DataFrame({
    'loan_amt': [df.loan_amt.sample(5).mean() for _ in range(10000)],
    'type': 'Mean of 5',
})

# %%
sample_mean_05.hist()
# Out:
# array([[<matplotlib.axes._subplots.AxesSubplot object at 0x7efbc2a79e50>]],
#       dtype=object)

# %%
sample_mean_20 = pd.DataFrame({
    'loan_amt': [df.loan_amt.sample(20).mean() for _ in range(10000)],
    'type': 'Mean of 20',
})

# %%
sample_data = pd.DataFrame({
    'loan_amt': df.loan_amt,
    'type': 'Data',
})

# %%
results = pd.concat([sample_data, sample_mean_05, sample_mean_20])

# %%
g = sns.FacetGrid(results, col='type', col_wrap=1, height=2,
                 aspect=2)
g.map(plt.hist, 'loan_amt', range=[0, df.loan_amt.max()], bins=40)
g.set_axis_labels('Loan Amt', 'Count')
g.set_titles('{col_name}')

# %% [markdown]
# ## Bootstrapping

# %%
from sklearn.utils import resample

# %%
results = []

for nrepeat in range(10000):
    sample = resample(df.loan_amt)
    results.append(sample.median())
results = pd.Series(results)
print('Bootstrap Statistics:')
print(f'original: {df.loan_amt.median()}')
print(f'bias: {results.mean() - df.loan_amt.median()}')
print(f'std. error: {results.std()}')
# Out:
# Bootstrap Statistics:
# original: 12825.0
# bias: -8.136500000000524
# std. error: 242.38354908201953

# %%
df.plot(kind='scatter', y='annual_inc', x='loan_amt', alpha=0.09, 
        figsize=(20,12), cmap='plasma', s=df['int_rate']**2.2,
        colorbar=True, c='loan_amt', label='Loan Amount')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 8654 entries, 0 to 8653
# Columns: 151 entries, id to loan_to_income_ratio
# dtypes: float64(102), int64(4), object(45)
# memory usage: 10.0+ MB

# %%
df.loan_amt.describe()
# Out:
# count     8654.000000
# mean     14968.185232
# std       9114.962599
# min       1000.000000
# 25%       8000.000000
# 50%      12800.000000
# 75%      20000.000000
# max      40000.000000
# Name: loan_amt, dtype: float64

# %% [markdown]
# ## QQ Plot

# %%
from scipy import stats

# %%
# Here we take the means to transform the original sample data
# to a normal distribution by using the Central Limit Theorem.

data = pd.Series([df.loan_amt.sample(100).mean() for i in range(1000)])

# %%
norm_sample = (data - data.mean())/data.std()

# %%
fig, ax = plt.subplots(figsize=(8,8))
#norm_sample = stats.norm.rvs(size=100)
stats.probplot(norm_sample, plot=ax)
plt.show()

# %%
# Normalizes the loan_amt data. Note that the data is not normally 
# distributed. It just puts it on the same scale as the normal dist
# for comparison purposes.
fig, ax = plt.subplots(figsize=(8,8))
norm_sample = (df.loan_amt - df.loan_amt.mean())/df.loan_amt.std()
stats.probplot(norm_sample, plot=ax)
plt.show()

# %%
fig, ax = plt.subplots(figsize=(8,8))
norm_sample = stats.norm.rvs(size=100)
stats.probplot(norm_sample, plot=ax)
plt.show()

# %%
# There appears to be a lot of outliers when it comes to 
# annual income. 
sns.set(style='whitegrid')
ax = sns.boxplot(x='annual_inc', data=dfe)

# %%
from sklearn.preprocessing import StandardScaler

# %%
features = list(dfe)

# %%
features
# Out:
# ['id',
#  'member_id',
#  'loan_amt',
#  'funded_amnt',
#  'funded_amnt_inv',
#  'term',
#  'int_rate',
#  'installment',
#  'grade',
#  'sub_grade',
#  'emp_title',
#  'emp_length',
#  'home_ownership',
#  'annual_inc',
#  'verification_status',
#  'issue_d',
#  'loan_status',
#  'pymnt_plan',
#  'url',
#  'desc',
#  'purpose',
#  'title',
#  'zip_code',
#  'addr_state',
#  'dti',
#  'delinq_2yrs',
#  'earliest_cr_line',
#  'inq_last_6mths',
#  'mths_since_last_delinq',
#  'mths_since_last_record',
#  'open_acc',
#  'pub_rec',
#  'revol_bal',
#  'revol_util',
#  'total_acc',
#  'initial_list_status',
#  'out_prncp',
#  'out_prncp_inv',
#  'total_pymnt',
#  'total_pymnt_inv',
#  'total_rec_prncp',
#  'total_rec_int',
#  'total_rec_late_fee',
#  'recoveries',
#  'collection_recovery_fee',
#  'last_pymnt_d',
#  'last_pymnt_amnt',
#  'next_pymnt_d',
#  'last_credit_pull_d',
#  'collections_12_mths_ex_med',
#  'mths_since_last_major_derog',
#  'policy_code',
#  'application_type',
#  'annual_inc_joint',
#  'dti_joint',
#  'verification_status_joint',
#  'acc_now_delinq',
#  'tot_coll_amt',
#  'tot_cur_bal',
#  'open_acc_6m',
#  'open_act_il',
#  'open_il_12m',
#  'open_il_24m',
#  'mths_since_rcnt_il',
#  'total_bal_il',
#  'il_util',
#  'open_rv_12m',
#  'open_rv_24m',
#  'max_bal_bc',
#  'all_util',
#  'total_rev_hi_lim',
#  'inq_fi',
#  'total_cu_tl',
#  'inq_last_12m',
#  'acc_open_past_24mths',
#  'avg_cur_bal',
#  'bc_open_to_buy',
#  'bc_util',
#  'chargeoff_within_12_mths',
#  'delinq_amnt',
#  'mo_sin_old_il_acct',
#  'mo_sin_old_rev_tl_op',
#  'mo_sin_rcnt_rev_tl_op',
#  'mo_sin_rcnt_tl',
#  'mort_acc',
#  'mths_since_recent_bc',
#  'mths_since_recent_bc_dlq',
#  'mths_since_recent_inq',
#  'mths_since_recent_revol_delinq',
#  'num_accts_ever_120_pd',
#  'num_actv_bc_tl',
#  'num_actv_rev_tl',
#  'num_bc_sats',
#  'num_bc_tl',
#  'num_il_tl',
#  'num_op_rev_tl',
#  'num_rev_accts',
#  'num_rev_tl_bal_gt_0',
#  'num_sats',
#  'num_tl_120dpd_2m',
#  'num_tl_30dpd',
#  'num_tl_90g_dpd_24m',
#  'num_tl_op_past_12m',
#  'pct_tl_nvr_dlq',
#  'percent_bc_gt_75',
#  'pub_rec_bankruptcies',
#  'tax_liens',
#  'tot_hi_cred_lim',
#  'total_bal_ex_mort',
#  'total_bc_limit',
#  'total_il_high_credit_limit',
#  'revol_bal_joint',
#  'sec_app_earliest_cr_line',
#  'sec_app_inq_last_6mths',
#  'sec_app_mort_acc',
#  'sec_app_open_acc',
#  'sec_app_revol_util',
#  'sec_app_open_act_il',
#  'sec_app_num_rev_accts',
#  'sec_app_chargeoff_within_12_mths',
#  'sec_app_collections_12_mths_ex_med',
#  'sec_app_mths_since_last_major_derog',
#  'hardship_flag',
#  'hardship_type',
#  'hardship_reason',
#  'hardship_status',
#  'deferral_term',
#  'hardship_amount',
#  'hardship_start_date',
#  'hardship_end_date',
#  'payment_plan_start_date',
#  'hardship_length',
#  'hardship_dpd',
#  'hardship_loan_status',
#  'orig_projected_additional_accrued_interest',
#  'hardship_payoff_balance_amount',
#  'hardship_last_payment_amount',
#  'disbursement_method',
#  'debt_settlement_flag',
#  'debt_settlement_flag_date',
#  'settlement_status',
#  'settlement_date',
#  'settlement_amount',
#  'settlement_percentage',
#  'settlement_term',
#  'issue_dt']

# %%
dfe.tail()
# Out:
#         id member_id  loan_amt  funded_amt  funded_amt_inv        term  \
# 2080  None      None     20000       20000           20000   60 months
# 2081  None      None      9800        9800            9800   36 months
# 2082  None      None      8725        8725            8725   36 months
# 2083  None      None     20000       20000           20000   36 months
# 2084  None      None     32000       32000           31968   60 months
#
#       int_rate  installment grade sub_grade     emp_title emp_length  \
# 2080     21.00       541.07     E        E2  oaks cleaner    6 years
# 2081      9.17       312.42     B        B1           CEO    9 years
# 2082     16.99       311.03     D        D1   supervayzer  10+ years
# 2083      6.03       608.72     A        A1           NCR  10+ years
# 2084     15.65       772.24     D        D4    FORD MOTOR  10+ years
#
#      home_ownership  annual_inc verification_status   issue_d  loan_status  \
# 2080            OWN       65000            Verified  May-2013  Charged Off
# 2081           RENT       36000            Verified  Oct-2014   Fully Paid
# 2082            OWN       28000        Not Verified  Jan-2014   Fully Paid
# 2083       MORTGAGE      140000            Verified  Aug-2013   Fully Paid
# 2084       MORTGAGE      104000            Verified  Feb-2011   Fully Paid
#
#      pymnt_plan   url  desc             purpose                    title  \
# 2080          n  None  None                 car     Automobile  purchase
# 2081          n  None  None         credit_card  Credit card refinancing
# 2082          n  None  None               other                    Other
# 2083          n  None  None  debt_consolidation       Debt Consolidation
# 2084          n  None  None         credit_card                  5 YEARS
#
#      zip_code addr_state    dti  delinq_2yrs earliest_cr_line  inq_last_6mths  \
# 2080    770xx         TX  23.13            0         Sep-1999               2
# 2081    891xx         NV  20.54            0         Nov-1995               0
# 2082    791xx         TX  23.75            0         Feb-2004               1
# 2083    153xx         PA  10.93            0         Feb-1997               0
# 2084    481xx         MI   5.35            0         Nov-1995               0
#
#       mths_since_last_delinq  mths_since_last_record  open_acc  pub_rec  \
# 2080                     NaN                     NaN         9        0
# 2081                     NaN                     NaN        22        0
# 2082                     NaN                     NaN        12        0
# 2083                     NaN                     NaN        10        0
# 2084                     NaN                     NaN         8        0
#
#       revol_bal  revol_util  total_acc initial_list_status  out_prncp  \
# 2080      16067        89.5         23                   w        0.0
# 2081      18989        38.8         42                   f        0.0
# 2082       5205        28.3         30                   f        0.0
# 2083      20538        34.6         16                   f        0.0
# 2084      17272        29.3         27                   f        0.0
#
#       out_prncp_inv   total_pymnt  total_pymnt_inv  total_rec_prncp  \
# 2080            0.0  16767.300000         16767.30          6523.21
# 2081            0.0  11246.450536         11246.45          9800.00
# 2082            0.0  10645.699998         10645.70          8725.00
# 2083            0.0  21913.560000         21913.56         20000.00
# 2084            0.0  37398.684776         37355.01         32000.00
#
#       total_rec_int  total_rec_late_fee  recoveries  collection_recovery_fee  \
# 2080        8085.68                 0.0     2158.41                 194.2569
# 2081        1446.45                 0.0        0.00                   0.0000
# 2082        1920.70                 0.0        0.00                   0.0000
# 2083        1913.56                 0.0        0.00                   0.0000
# 2084        5398.68                 0.0        0.00                   0.0000
#
#      last_pymnt_d  last_pymnt_amnt next_pymnt_d last_credit_pull_d  \
# 2080     Aug-2015           541.07                        Oct-2016
# 2081     Sep-2017           624.17                        Feb-2019
# 2082     Sep-2015          4736.27                        Sep-2015
# 2083     Aug-2016           608.36                        Aug-2016
# 2084     May-2012         27369.58                        May-2012
#
#       collections_12_mths_ex_med  mths_since_last_major_derog  policy_code  \
# 2080                         0.0                          NaN            1
# 2081                         0.0                          NaN            1
# 2082                         0.0                          NaN            1
# 2083                         0.0                          NaN            1
# 2084                         0.0                          NaN            1
#
#      application_type  annual_inc_joint  dti_joint verification_status_joint  \
# 2080       Individual               NaN        NaN                      None
# 2081       Individual               NaN        NaN                      None
# 2082       Individual               NaN        NaN                      None
# 2083       Individual               NaN        NaN                      None
# 2084       Individual               NaN        NaN                      None
#
#       acc_now_delinq  tot_coll_amt  tot_cur_bal  open_acc_6m  open_act_il  \
# 2080               0           0.0      47140.0          NaN          NaN
# 2081               0           0.0      43718.0          NaN          NaN
# 2082               0        1466.0      19869.0          NaN          NaN
# 2083               0           0.0      90083.0          NaN          NaN
# 2084               0           NaN          NaN          NaN          NaN
#
#       open_il_12m  open_il_24m  mths_since_rcnt_il  total_bal_il  il_util  \
# 2080          NaN          NaN                 NaN           NaN      NaN
# 2081          NaN          NaN                 NaN           NaN      NaN
# 2082          NaN          NaN                 NaN           NaN      NaN
# 2083          NaN          NaN                 NaN           NaN      NaN
# 2084          NaN          NaN                 NaN           NaN      NaN
#
#       open_rv_12m  open_rv_24m  max_bal_bc  all_util  total_rev_hi_lim  \
# 2080          NaN          NaN         NaN       NaN           17948.0
# 2081          NaN          NaN         NaN       NaN           48900.0
# 2082          NaN          NaN         NaN       NaN           18400.0
# 2083          NaN          NaN         NaN       NaN           59300.0
# 2084          NaN          NaN         NaN       NaN               NaN
#
#       inq_fi  total_cu_tl  inq_last_12m  acc_open_past_24mths  avg_cur_bal  \
# 2080     NaN          NaN           NaN                   3.0       5893.0
# 2081     NaN          NaN           NaN                   2.0       1987.0
# 2082     NaN          NaN           NaN                   5.0       1987.0
# 2083     NaN          NaN           NaN                   3.0      11260.0
# 2084     NaN          NaN           NaN                   NaN          NaN
#
#       bc_open_to_buy  bc_util  chargeoff_within_12_mths  delinq_amnt  \
# 2080           281.0     98.3                       0.0            0
# 2081         19747.0     24.6                       0.0            0
# 2082          4972.0     41.5                       0.0            0
# 2083         30686.0     39.7                       0.0            0
# 2084             NaN      NaN                       0.0            0
#
#       mo_sin_old_il_acct  mo_sin_old_rev_tl_op  mo_sin_rcnt_rev_tl_op  \
# 2080               166.0                  69.0                   16.0
# 2081               179.0                 226.0                   18.0
# 2082               119.0                 111.0                    2.0
# 2083               149.0                 200.0                    1.0
# 2084                 NaN                   NaN                    NaN
#
#       mo_sin_rcnt_tl  mort_acc  mths_since_recent_bc  \
# 2080            16.0       0.0                  22.0
# 2081            18.0       0.0                  18.0
# 2082             2.0       2.0                  11.0
# 2083             1.0       2.0                   1.0
# 2084             NaN       NaN                   NaN
#
#       mths_since_recent_bc_dlq  mths_since_recent_inq  \
# 2080                       NaN                    4.0
# 2081                       NaN                   12.0
# 2082                       NaN                    2.0
# 2083                       NaN                    NaN
# 2084                       NaN                    NaN
#
#       mths_since_recent_revol_delinq  num_accts_ever_120_pd  num_actv_bc_tl  \
# 2080                             NaN                    0.0             4.0
# 2081                             NaN                    0.0             5.0
# 2082                             NaN                    0.0             3.0
# 2083                             NaN                    0.0             4.0
# 2084                             NaN                    NaN             NaN
#
#       num_actv_rev_tl  num_bc_sats  num_bc_tl  num_il_tl  num_op_rev_tl  \
# 2080              4.0          4.0       10.0        5.0            7.0
# 2081              8.0          7.0        9.0       27.0           11.0
# 2082              7.0          6.0       12.0        5.0           11.0
# 2083              5.0          5.0        8.0        1.0            8.0
# 2084              NaN          NaN        NaN        NaN            NaN
#
#       num_rev_accts  num_rev_tl_bal_gt_0  num_sats  num_tl_120dpd_2m  \
# 2080           18.0                  4.0       9.0               0.0
# 2081           15.0                  8.0      22.0               0.0
# 2082           22.0                  7.0      12.0               0.0
# 2083           13.0                  5.0      10.0               0.0
# 2084            NaN                  NaN       NaN               NaN
#
#       num_tl_30dpd  num_tl_90g_dpd_24m  num_tl_op_past_12m  pct_tl_nvr_dlq  \
# 2080           0.0                 0.0                 0.0           100.0
# 2081           0.0                 0.0                 0.0           100.0
# 2082           0.0                 0.0                 3.0           100.0
# 2083           0.0                 0.0                 2.0           100.0
# 2084           NaN                 NaN                 NaN             NaN
#
#       percent_bc_gt_75  pub_rec_bankruptcies  tax_liens  tot_hi_cred_lim  \
# 2080             100.0                   0.0        0.0          67621.0
# 2081               0.0                   0.0        0.0          69119.0
# 2082              25.0                   0.0        0.0          35595.0
# 2083               0.0                   0.0        0.0         139970.0
# 2084               NaN                   0.0        0.0              NaN
#
#       total_bal_ex_mort  total_bc_limit  total_il_high_credit_limit  \
# 2080            47140.0         16348.0                     49673.0
# 2081            43718.0         26200.0                     20219.0
# 2082            19869.0          8500.0                     17195.0
# 2083            20538.0         50900.0                         0.0
# 2084                NaN             NaN                         NaN
#
#       revol_bal_joint sec_app_earliest_cr_line  sec_app_inq_last_6mths  \
# 2080              NaN                     None                     NaN
# 2081              NaN                     None                     NaN
# 2082              NaN                     None                     NaN
# 2083              NaN                     None                     NaN
# 2084              NaN                     None                     NaN
#
#       sec_app_mort_acc  sec_app_open_acc  sec_app_revol_util  \
# 2080               NaN               NaN                 NaN
# 2081               NaN               NaN                 NaN
# 2082               NaN               NaN                 NaN
# 2083               NaN               NaN                 NaN
# 2084               NaN               NaN                 NaN
#
#       sec_app_open_act_il  sec_app_num_rev_accts  \
# 2080                  NaN                    NaN
# 2081                  NaN                    NaN
# 2082                  NaN                    NaN
# 2083                  NaN                    NaN
# 2084                  NaN                    NaN
#
#       sec_app_chargeoff_within_12_mths  sec_app_collections_12_mths_ex_med  \
# 2080                               NaN                                 NaN
# 2081                               NaN                                 NaN
# 2082                               NaN                                 NaN
# 2083                               NaN                                 NaN
# 2084                               NaN                                 NaN
#
#       sec_app_mths_since_last_major_derog hardship_flag hardship_type  \
# 2080                                  NaN             N          None
# 2081                                  NaN             N          None
# 2082                                  NaN             N          None
# 2083                                  NaN             N          None
# 2084                                  NaN             N          None
#
#      hardship_reason hardship_status  deferral_term  hardship_amount  \
# 2080            None            None            NaN              NaN
# 2081            None            None            NaN              NaN
# 2082            None            None            NaN              NaN
# 2083            None            None            NaN              NaN
# 2084            None            None            NaN              NaN
#
#      hardship_start_date hardship_end_date payment_plan_start_date  \
# 2080                None              None                    None
# 2081                None              None                    None
# 2082                None              None                    None
# 2083                None              None                    None
# 2084                None              None                    None
#
#       hardship_length  hardship_dpd hardship_loan_status  \
# 2080              NaN           NaN                 None
# 2081              NaN           NaN                 None
# 2082              NaN           NaN                 None
# 2083              NaN           NaN                 None
# 2084              NaN           NaN                 None
#
#       orig_projected_additional_accrued_interest  \
# 2080                                         NaN
# 2081                                         NaN
# 2082                                         NaN
# 2083                                         NaN
# 2084                                         NaN
#
#       hardship_payoff_balance_amount  hardship_last_payment_amount  \
# 2080                             NaN                           NaN
# 2081                             NaN                           NaN
# 2082                             NaN                           NaN
# 2083                             NaN                           NaN
# 2084                             NaN                           NaN
#
#      disbursement_method debt_settlement_flag debt_settlement_flag_date  \
# 2080                Cash                    N                      None
# 2081                Cash                    N                      None
# 2082                Cash                    N                      None
# 2083                Cash                    N                      None
# 2084                Cash                    N                      None
#
#      settlement_status settlement_date  settlement_amount  \
# 2080              None            None                NaN
# 2081              None            None                NaN
# 2082              None            None                NaN
# 2083              None            None                NaN
# 2084              None            None                NaN
#
#       settlement_percentage  settlement_term    issue_dt last_pymnt_dt  \
# 2080                    NaN              NaN  2013-05-01    2015-08-01
# 2081                    NaN              NaN  2014-10-01    2017-09-01
# 2082                    NaN              NaN  2014-01-01    2015-09-01
# 2083                    NaN              NaN  2013-08-01    2016-08-01
# 2084                    NaN              NaN  2011-02-01    2012-05-01
#
#      next_pymnt_dt last_credit_pull_dt  loan_gt_income  loan_to_income_ratio
# 2080    1900-01-01          2016-10-01           False              0.307692
# 2081    1900-01-01          2019-02-01           False              0.272222
# 2082    1900-01-01          2015-09-01           False              0.311607
# 2083    1900-01-01          2016-08-01           False              0.142857
# 2084    1900-01-01          2012-05-01           False              0.307692
