# %% [markdown]
# ## ML Practice: Analyzing Lending Club Loan Data
#
# We will take the features to determine what the qualifying loan amount that the individual would be approved for.

# %%
import psycopg2 as pg
import pandas as pd
import numpy as np
import zipfile
import sqlalchemy
import os 
# %matplotlib inline
from matplotlib import pyplot as plt
import seaborn as sns
from utils.secrets import creds

# %%
pd.options.display.max_columns = 170

# %%
creds = creds['postgres']

# %%
# Changed Username & Password to import from secrets file.
conn_str = f"postgresql+psycopg2://{creds['username']}:{creds['password']}@localhost/Kaggle"
engine = sqlalchemy.create_engine(conn_str)
metadata = sqlalchemy.MetaData(schema='lending_club')

# %% [markdown]
# # Lending Tree Data

# %%
# Only used for loading a couple rows into the database to create the underlying columns + datatypes
# Later import csv using dbeaver. 

# file = os.path.expanduser('~') + '/datasets/loan.csv'
# pd.read_csv(file, nrows=3).to_sql('loan', con=engine, index=False, if_exists='replace', schema='lending_club')

# %%
df = pd.read_sql('select * from lending_club.loan tablesample system(.4)', con=engine)

# %%
df.shape
# Out:
# (8781, 151)

# %%
hist = df.loan_amt.hist()

# %%
sample_mean_05 = pd.DataFrame({
    'loan_amt': [df.loan_amt.sample(5).mean() for _ in range(10000)],
    'type': 'Mean of 5',
})

# %%
sample_mean_05.hist()
# Out:
# array([[<matplotlib.axes._subplots.AxesSubplot object at 0x7efbcd59a160>]],
#       dtype=object)

# %%
sample_mean_20 = pd.DataFrame({
    'loan_amt': [df.loan_amt.sample(20).mean() for _ in range(10000)],
    'type': 'Mean of 20',
})

# %%
sample_data = pd.DataFrame({
    'loan_amt': df.loan_amt,
    'type': 'Data',
})

# %%
results = pd.concat([sample_data, sample_mean_05, sample_mean_20])

# %%
g = sns.FacetGrid(results, col='type', col_wrap=1, height=2,
                 aspect=2)
g.map(plt.hist, 'loan_amt', range=[0, df.loan_amt.max()], bins=40)
g.set_axis_labels('Loan Amt', 'Count')
g.set_titles('{col_name}')

# %% [markdown]
# ## Bootstrapping

# %%
from sklearn.utils import resample

# %%
results = []

for nrepeat in range(10000):
    sample = resample(df.loan_amt)
    results.append(sample.median())
results = pd.Series(results)
print('Bootstrap Statistics:')
print(f'original: {df.loan_amt.median()}')
print(f'bias: {results.mean() - df.loan_amt.median()}')
print(f'std. error: {results.std()}')
# Out:
# Bootstrap Statistics:
# original: 12500.0
# bias: 15.594999999999345
# std. error: 361.4213033439889

# %%
df.plot(kind='scatter', y='annual_inc', x='loan_amt', alpha=0.09, 
        figsize=(20,12), cmap='plasma', s=df['int_rate']**2.2,
        colorbar=True, c='loan_amt', label='Loan Amount')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 8781 entries, 0 to 8780
# Columns: 151 entries, id to loan_to_income_ratio
# dtypes: bool(1), float64(92), int64(16), object(42)
# memory usage: 10.1+ MB

# %%
df.loan_amt.describe()
# Out:
# count     8781.000000
# mean     14921.987815
# std       9188.288243
# min        550.000000
# 25%       8000.000000
# 50%      12500.000000
# 75%      20000.000000
# max      40000.000000
# Name: loan_amt, dtype: float64

# %% [markdown]
# ## QQ Plot

# %%
from scipy import stats

# %%
# Here we take the means to transform the original sample data
# to a normal distribution by using the Central Limit Theorem.

data = pd.Series([df.loan_amt.sample(100).mean() for i in range(1000)])

# %%
norm_sample = (data - data.mean())/data.std()

# %%
fig, ax = plt.subplots(figsize=(8,8))
#norm_sample = stats.norm.rvs(size=100)
stats.probplot(norm_sample, plot=ax)
plt.show()

# %%
# Normalizes the loan_amt data. Note that the data is not normally 
# distributed. It just puts it on the same scale as the normal dist
# for comparison purposes.
fig, ax = plt.subplots(figsize=(8,8))
norm_sample = (df.loan_amt - df.loan_amt.mean())/df.loan_amt.std()
stats.probplot(norm_sample, plot=ax)
plt.show()

# %%
fig, ax = plt.subplots(figsize=(8,8))
norm_sample = stats.norm.rvs(size=100)
stats.probplot(norm_sample, plot=ax)
plt.show()

# %%
# There appears to be a lot of outliers when it comes to 
# annual income. 
sns.set(style='whitegrid')
ax = sns.boxplot(x='annual_inc', data=df)

# %%
from sklearn.preprocessing import StandardScaler

# %%
features = list(df)

# %%
features
# Out:
# ['id',
#  'member_id',
#  'loan_amt',
#  'funded_amt',
#  'funded_amt_inv',
#  'term',
#  'int_rate',
#  'installment',
#  'grade',
#  'sub_grade',
#  'emp_title',
#  'emp_length',
#  'home_ownership',
#  'annual_inc',
#  'verification_status',
#  'issue_d',
#  'loan_status',
#  'pymnt_plan',
#  'url',
#  'desc',
#  'purpose',
#  'title',
#  'zip_code',
#  'addr_state',
#  'dti',
#  'delinq_2yrs',
#  'earliest_cr_line',
#  'inq_last_6mths',
#  'mths_since_last_delinq',
#  'mths_since_last_record',
#  'open_acc',
#  'pub_rec',
#  'revol_bal',
#  'revol_util',
#  'total_acc',
#  'initial_list_status',
#  'out_prncp',
#  'out_prncp_inv',
#  'total_pymnt',
#  'total_pymnt_inv',
#  'total_rec_prncp',
#  'total_rec_int',
#  'total_rec_late_fee',
#  'recoveries',
#  'collection_recovery_fee',
#  'last_pymnt_d',
#  'last_pymnt_amnt',
#  'next_pymnt_d',
#  'last_credit_pull_d',
#  'collections_12_mths_ex_med',
#  'mths_since_last_major_derog',
#  'policy_code',
#  'application_type',
#  'annual_inc_joint',
#  'dti_joint',
#  'verification_status_joint',
#  'acc_now_delinq',
#  'tot_coll_amt',
#  'tot_cur_bal',
#  'open_acc_6m',
#  'open_act_il',
#  'open_il_12m',
#  'open_il_24m',
#  'mths_since_rcnt_il',
#  'total_bal_il',
#  'il_util',
#  'open_rv_12m',
#  'open_rv_24m',
#  'max_bal_bc',
#  'all_util',
#  'total_rev_hi_lim',
#  'inq_fi',
#  'total_cu_tl',
#  'inq_last_12m',
#  'acc_open_past_24mths',
#  'avg_cur_bal',
#  'bc_open_to_buy',
#  'bc_util',
#  'chargeoff_within_12_mths',
#  'delinq_amnt',
#  'mo_sin_old_il_acct',
#  'mo_sin_old_rev_tl_op',
#  'mo_sin_rcnt_rev_tl_op',
#  'mo_sin_rcnt_tl',
#  'mort_acc',
#  'mths_since_recent_bc',
#  'mths_since_recent_bc_dlq',
#  'mths_since_recent_inq',
#  'mths_since_recent_revol_delinq',
#  'num_accts_ever_120_pd',
#  'num_actv_bc_tl',
#  'num_actv_rev_tl',
#  'num_bc_sats',
#  'num_bc_tl',
#  'num_il_tl',
#  'num_op_rev_tl',
#  'num_rev_accts',
#  'num_rev_tl_bal_gt_0',
#  'num_sats',
#  'num_tl_120dpd_2m',
#  'num_tl_30dpd',
#  'num_tl_90g_dpd_24m',
#  'num_tl_op_past_12m',
#  'pct_tl_nvr_dlq',
#  'percent_bc_gt_75',
#  'pub_rec_bankruptcies',
#  'tax_liens',
#  'tot_hi_cred_lim',
#  'total_bal_ex_mort',
#  'total_bc_limit',
#  'total_il_high_credit_limit',
#  'revol_bal_joint',
#  'sec_app_earliest_cr_line',
#  'sec_app_inq_last_6mths',
#  'sec_app_mort_acc',
#  'sec_app_open_acc',
#  'sec_app_revol_util',
#  'sec_app_open_act_il',
#  'sec_app_num_rev_accts',
#  'sec_app_chargeoff_within_12_mths',
#  'sec_app_collections_12_mths_ex_med',
#  'sec_app_mths_since_last_major_derog',
#  'hardship_flag',
#  'hardship_type',
#  'hardship_reason',
#  'hardship_status',
#  'deferral_term',
#  'hardship_amount',
#  'hardship_start_date',
#  'hardship_end_date',
#  'payment_plan_start_date',
#  'hardship_length',
#  'hardship_dpd',
#  'hardship_loan_status',
#  'orig_projected_additional_accrued_interest',
#  'hardship_payoff_balance_amount',
#  'hardship_last_payment_amount',
#  'disbursement_method',
#  'debt_settlement_flag',
#  'debt_settlement_flag_date',
#  'settlement_status',
#  'settlement_date',
#  'settlement_amount',
#  'settlement_percentage',
#  'settlement_term',
#  'issue_dt',
#  'last_pymnt_dt',
#  'next_pymnt_dt',
#  'last_credit_pull_dt',
#  'loan_gt_income',
#  'loan_to_income_ratio']

# %%
df.tail()
# Out:
#         id member_id  loan_amt  funded_amt  funded_amt_inv        term  \
# 8776  None      None     16500       16500           16250   36 months
# 8777  None      None     30000       30000           29975   36 months
# 8778  None      None     18000       18000           18000   36 months
# 8779  None      None      6000        6000            6000   36 months
# 8780  None      None      9500        9500            9500   36 months
#
#       int_rate  installment grade sub_grade                      emp_title  \
# 8776      9.44       528.09     B        B1               Business Analyst
# 8777     22.91      1159.89     E        E1   Business Development Manager
# 8778     22.91       695.94     E        E1                        Advisor
# 8779     12.62       201.07     C        C1                      Secretary
# 8780     22.91       367.30     E        E1  Raw/Finish perator Technician
#
#      emp_length home_ownership  annual_inc verification_status   issue_d  \
# 8776  10+ years       MORTGAGE      150000     Source Verified  Oct-2017
# 8777  10+ years       MORTGAGE       79000            Verified  Oct-2017
# 8778    6 years            OWN       50000            Verified  Oct-2017
# 8779    4 years           RENT       20500     Source Verified  Oct-2017
# 8780     1 year           RENT       55000     Source Verified  Oct-2017
#
#      loan_status pymnt_plan   url  desc             purpose  \
# 8776     Current          n  None   NaN         credit_card
# 8777     Current          n  None   NaN  debt_consolidation
# 8778     Current          n  None   NaN  debt_consolidation
# 8779     Current          n  None   NaN         credit_card
# 8780     Current          n  None   NaN  debt_consolidation
#
#                         title zip_code addr_state    dti  delinq_2yrs  \
# 8776  Credit card refinancing    775xx         TX  17.55            0
# 8777       Debt consolidation    360xx         AL  29.71            0
# 8778       Debt consolidation    605xx         IL  36.27            0
# 8779  Credit card refinancing    074xx         NJ  27.81            0
# 8780       Debt consolidation    953xx         CA  22.06            0
#
#      earliest_cr_line  inq_last_6mths  mths_since_last_delinq  \
# 8776         Feb-2001               1                    54.0
# 8777         Jul-1993               0                    24.0
# 8778         Sep-1998               0                    71.0
# 8779         Jul-1996               1                     NaN
# 8780         Apr-2006               0                    36.0
#
#       mths_since_last_record  open_acc  pub_rec  revol_bal  revol_util  \
# 8776                     NaN        18        0      16040        47.5
# 8777                     NaN        11        0      18510        79.8
# 8778                     NaN        15        0      19336        80.6
# 8779                     NaN        15        0       5513        23.0
# 8780                     NaN        16        0      18743        49.8
#
#       total_acc initial_list_status  out_prncp  out_prncp_inv  total_pymnt  \
# 8776         42                   f    9737.21        9589.67      8497.04
# 8777         26                   f   19190.37       19174.38     18746.70
# 8778         44                   f   11489.30       11489.30     11112.13
# 8779         35                   w    3609.52        3609.52      3212.91
# 8780         20                   f    6058.75        6058.75      5864.71
#
#       total_pymnt_inv  total_rec_prncp  total_rec_int  total_rec_late_fee  \
# 8776          8368.30          6762.79        1734.25                0.00
# 8777         18731.08         10809.63        7763.10              173.97
# 8778         11112.13          6510.70        4601.43                0.00
# 8779          3212.91          2390.48         822.43                0.00
# 8780          5864.71          3441.25        2423.46                0.00
#
#       recoveries  collection_recovery_fee last_pymnt_d  last_pymnt_amnt  \
# 8776         0.0                      0.0     Feb-2019           528.09
# 8777         0.0                      0.0     Feb-2019          1217.88
# 8778         0.0                      0.0     Feb-2019           695.94
# 8779         0.0                      0.0     Feb-2019           201.07
# 8780         0.0                      0.0     Feb-2019           367.30
#
#      next_pymnt_d last_credit_pull_d  collections_12_mths_ex_med  \
# 8776     Mar-2019           Feb-2019                           0
# 8777     Mar-2019           Feb-2019                           0
# 8778     Mar-2019           Feb-2019                           0
# 8779     Mar-2019           Feb-2019                           0
# 8780     Mar-2019           Feb-2019                           0
#
#       mths_since_last_major_derog  policy_code application_type  \
# 8776                         54.0            1       Individual
# 8777                         24.0            1       Individual
# 8778                          NaN            1       Individual
# 8779                          NaN            1       Individual
# 8780                         36.0            1       Individual
#
#       annual_inc_joint  dti_joint verification_status_joint  acc_now_delinq  \
#
ol_bal_joint sec_app_earliest_cr_line  sec_app_inq_last_6mths  \
# 8776              NaN                     None                     NaN
# 8777              NaN                     None                     NaN
# 8778              NaN                     None                     NaN
# 8779              NaN                     None                     NaN
# 8780              NaN                     None                     NaN
#
#       sec_app_mort_acc  sec_app_open_acc  sec_app_revol_util  \
# 8776               NaN               NaN                 NaN
# 8777               NaN               NaN                 NaN
# 8778               NaN               NaN                 NaN
# 8779               NaN               NaN                 NaN
# 8780               NaN               NaN                 NaN
#
#       sec_app_open_act_il  sec_app_num_rev_accts  \
# 8776                  NaN                    NaN
# 8777                  NaN                    NaN
# 8778                  NaN                    NaN
# 8779                  NaN                    NaN
# 8780                  NaN                    NaN
#
#       sec_app_chargeoff_within_12_mths  sec_app_collections_12_mths_ex_med  \
# 8776                               NaN                                 NaN
# 8777                               NaN                                 NaN
# 8778                               NaN                                 NaN
# 8779                               NaN                                 NaN
# 8780                               NaN                                 NaN
#
#       sec_app_mths_since_last_major_derog hardship_flag hardship_type  \
# 8776                                  NaN             N          None
# 8777                                  NaN             N          None
# 8778                                  NaN             N          None
# 8779                                  NaN             N          None
# 8780                                  NaN             N          None
#
#      hardship_reason hardship_status  deferral_term  hardship_amount  \
# 8776            None            None            NaN              NaN
# 8777            None            None            NaN              NaN
# 8778            None            None            NaN              NaN
# 8779            None            None            NaN              NaN
# 8780            None            None            NaN              NaN
#
#      hardship_start_date hardship_end_date payment_plan_start_date  \
# 8776                None              None                    None
# 8777                None              None                    None
# 8778                None              None                    None
# 8779                None              None                    None
# 8780                None              None                    None
#
#       hardship_length  hardship_dpd hardship_loan_status  \
# 8776              NaN           NaN                 None
# 8777              NaN           NaN                 None
# 8778              NaN           NaN                 None
# 8779              NaN           NaN                 None
# 8780              NaN           NaN                 None
#
#       orig_projected_additional_accrued_interest  \
# 8776                                         NaN
# 8777                                         NaN
# 8778                                         NaN
# 8779                                         NaN
# 8780                                         NaN
#
#       hardship_payoff_balance_amount  hardship_last_payment_amount  \
# 8776                             NaN                           NaN
# 8777                             NaN                           NaN
# 8778                             NaN                           NaN
# 8779                             NaN                           NaN
# 8780                             NaN                           NaN
#
#      disbursement_method debt_settlement_flag debt_settlement_flag_date  \
# 8776                Cash                    N                      None
# 8777                Cash                    N                      None
# 8778                Cash                    N                      None
# 8779                Cash                    N                      None
# 8780                Cash                    N                      None
#
#      settlement_status settlement_date  settlement_amount  \
# 8776              None            None                NaN
# 8777              None            None                NaN
# 8778              None            None                NaN
# 8779              None            None                NaN
# 8780              None            None                NaN
#
#       settlement_percentage  settlement_term    issue_dt last_pymnt_dt  \
# 8776                    NaN              NaN  2017-10-01    2019-02-01
# 8777                    NaN              NaN  2017-10-01    2019-02-01
# 8778                    NaN              NaN  2017-10-01    2019-02-01
# 8779                    NaN              NaN  2017-10-01    2019-02-01
# 8780                    NaN              NaN  2017-10-01    2019-02-01
#
#      next_pymnt_dt last_credit_pull_dt  loan_gt_income  loan_to_income_ratio
# 8776    2019-03-01          2019-02-01           False              0.110000
# 8777    2019-03-01          2019-02-01           False              0.379747
# 8778    2019-03-01          2019-02-01           False              0.360000
# 8779    2019-03-01          2019-02-01           False              0.292683
# 8780    2019-03-01          2019-02-01           False              0.172727

# %%
df.annual_inc.describe()
# Out:
# count    8.781000e+03
# mean     7.923079e+04
# std      1.316062e+05
# min      0.000000e+00
# 25%      4.551000e+04
# 50%      6.500000e+04
# 75%      9.450000e+04
# max      9.573072e+06
# Name: annual_inc, dtype: float64

# %%
from random import randint

# %%
dist = [randint(0,1) for i in range(100000)]

# %%
pd.Series(dist).value_counts()
# Out:
# 1    50046
# 0    49954
# dtype: int64

# %%
from scipy.stats import binom

# %%
binom.pmf(2, n=5, p=0.1)
# Out:
# 0.0729

# %%
binom.cdf(2, n=5, p=0.1)
# Out:
# 0.99144
