# %% [markdown]
# ## ML Practice: Analyzing Lending Club Loan Data

# %%
import psycopg2 as pg
import pandas as pd
import numpy as np
import zipfile
import sqlalchemy
import os

# %%
conn_str = "postgresql+psycopg2://wolfgang:patton@localhost/kaggle"
engine = sqlalchemy.create_engine(conn_str)
metadata = sqlalchemy.MetaData(schema='lending_club')

# %% [markdown]
# # Lending Tree Data

# %%
pd.read_csv('/home/wolfgang/datasets/loan.csv').\
            to_sql('loan', con=engine, index=False, 
                   if_exists='replace',schema='lending_club',
                   chunksize=1000)

# %% [markdown]
# # Lending Tree Data

# %%
df = pd.read_sql('SELECT * FROM lending.RENT', con=engine)

# %%
df.columns
# Out:
# Index(['created_on', 'operation', 'property_type', 'place_name',
#        'place_with_parent_names', 'geonames_id', 'lat-lon', 'lat', 'lon',
#        'price', 'currency', 'price_aprox_local_currency', 'price_aprox_usd',
#        'surface_total_in_m2', 'surface_covered_in_m2', 'price_usd_per_m2',
#        'price_per_m2', 'floor', 'rooms', 'expenses', 'description', 'title'],
#       dtype='object')

# %%
df.head()
# Out:
#    created_on operation property_type   place_name  \
# 0  2013-12-05      rent         house       Jardim
# 1  2013-12-05      rent         store    Vila Olga
# 2  2013-12-05      rent         store    Vila Olga
# 3  2013-12-05      rent     apartment  Santo André
# 4  2013-12-05      rent         house  Santo André
#
#                              place_with_parent_names  geonames_id lat-lon  \
# 0              |Brasil|São Paulo|Santo André|Jardim|          NaN    None
# 1  |Brasil|São Paulo|São Bernardo do Campo|Vila O...          NaN    None
# 2  |Brasil|São Paulo|São Bernardo do Campo|Vila O...          NaN    None
# 3                     |Brasil|São Paulo|Santo André|          NaN    None
# 4                     |Brasil|São Paulo|Santo André|          NaN    None
#
#    lat  lon   price  ... price_aprox_usd  surface_total_in_m2  \
# 0  NaN  NaN  3000.0  ...          936.15                  NaN
# 1  NaN  NaN  5000.0  ...         1560.25                  NaN
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 97353 entries, 0 to 97352
# Data columns (total 22 columns):
#  #   Column                      Non-Null Count  Dtype
# ---  ------                      --------------  -----
#  0   created_on                  97353 non-null  object
#  1   operation                   97353 non-null  object
#  2   property_type               97353 non-null  object
#  3   place_name                  97353 non-null  object
#  4   place_with_parent_names     97353 non-null  object
#  5   geonames_id                 3 non-null      float64
#  6   lat-lon                     46030 non-null  object
#  7   lat                         46030 non-null  float64
#  8   lon                         46030 non-null  float64
#  9   price                       92334 non-null  float64
#  10  currency                    92333 non-null  object
#  11  price_aprox_local_currency  92334 non-null  float64
#  12  price_aprox_usd             92334 non-null  float64
# ...

# %%
df.describe()
# Out:
#        geonames_id           lat           lon          price  \
# count          3.0  46030.000000  46030.000000   92334.000000
# mean     4164138.0    -22.861939    -46.707036    3935.703554
# std            0.0      3.585125      2.672557    9325.828330
# min      4164138.0    -33.692432    -97.497955       0.000000
# 25%      4164138.0    -23.619106    -47.024731    1140.000000
# 50%      4164138.0    -23.562963    -46.671908    1900.000000
# 75%      4164138.0    -23.030475    -46.567808    3600.000000
# max      4164138.0     25.860630    -34.813914  470000.000000
#
#        price_aprox_local_currency  price_aprox_usd  surface_total_in_m2  \
# count                92334.000000     92334.000000         15848.000000
# mean                  3928.693581      1228.255667           234.658695
# std                   9197.214373      2875.387441          2444.656264
# min                      0.000000         0.000000             0.000000
# ...

# %%
# %matplotlib inline
import matplotlib.pyplot as plt

# %%
df.hist(bins=100, figsize=(30,25))
plt.show()

# %%
df.price.hist(bins=500, figsize=(25,15))
plt.show()

# %%
df.property_type.value_counts()
# Out:
# apartment    57938
# house        20244
# store        18665
# PH             506
# Name: property_type, dtype: int64
